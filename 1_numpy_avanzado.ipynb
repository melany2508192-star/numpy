# %% [markdown]
# <a href="https://colab.research.google.com/github/melany2508192-star/numpy/blob/main/1_numpy_avanzado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hola Cientificos

# %%
import numpy as np

# %%
lista = [[1, 2, 3, 4],[3, 4, 5, 6], [5, 6, 7, 8]]

array_1d = np.array(lista, dtype='float')


#Checamos el tipo de dato de array_id
type(array_1d)

#contenido del array
array_1d
# Out:
# array([[1., 2., 3., 4.],
#        [3., 4., 5., 6.],
#        [5., 6., 7., 8.]])

# %%
# ndim
print('Dimensiones: ', array_1d.ndim)
# shape
print("Shape: ", array_1d.shape)
# size
print("Size: ", array_1d.size)
# Out:
# Dimensiones:  2
# Shape:  (3, 4)
# Size:  12

# %% [markdown]
# # Hola Cientificos

# %%
import random

# %%
def generar_matriz(N):
    matriz= []
    for i in range (N):
        fila = []
        for j in range(N):
            fila.append(random.randint(1, 9))
        matriz.append(fila)
    return matriz

N = 5

matriz_aleatoria = generar_matriz(N)
for fila in matriz_aleatoria:
    print(fila)

def imprimir_matriz(matriz):
    for fila in matriz:
        fila_formateada = ' '.join(f'{elemento:2}' for elemento in fila)
        print(fila_formateada)
# Out:
# [3, 6, 6, 2, 8]
# [2, 4, 6, 3, 1]
# [5, 1, 2, 1, 2]
# [7, 7, 4, 5, 9]
# [1, 1, 3, 7, 1]

# %%
print("Matriz de 5x5")
m_5 = generar_matriz(5)
imprimir_matriz(m_5)
print("============")
print("Matriz de 10x10")
m_10 = generar_matriz(10)
imprimir_matriz(m_10)
print("============")
print("Matriz de 20x20")
m_20 = generar_matriz(20)
imprimir_matriz(m_20)
# Out:
# Matriz de 5x5
#  5  4  8  2  5
#  4  2  6  1  9
#  2  2  2  9  3
#  9  7  2  7  7
#  9  1  6  4  1
# ...
# Matriz de 10x10
#  2  5  6  2  1  6  9  7  1  9
#  3  5  1  1  1  8  5  4  2  6
#  2  8  4  9  2  6  4  3  5  1
#  3  8  1  5  5  8  4  5  1  6
#  9  2  9  3  2  8  3  6  4  9
#  5  7  7  8  6  6  4  4  2  8
#  8  9  3  1  4  3  3  3  8  6
#  8  1  2  3  9  3  9  7  7  5
#  5  3  1  5  6  1  1  8  4  7
#  5  2  5  1  6  5  6  4  2  4
# ...
# Matriz de 20x20
#  8  8  1  8  3  2  7  2  1  6  1  6  2  1  1  8  3  8  9  7
#  2  7  2  8  1  8  8  6  4  9  2  6  4  9  6  8  3  9  2  8
#  1  9  1  5  8  8  1  3  6  8  4  3  3  2  3  5  7  2  4  2
#  3  6  4  9  5  2  5  9  1  9  2  1  5  8  6  5  1  3  8  2
#  2  2  1  2  3  5  5  7  7  2  1  5  3  3  3  3  9  3  7  7
#  5  1  5  5  7  3  9  7  1  5  8  6  6  6  8  9  3  8  5  6
#  2  6  4  1  7  1  9  2  9  6  6  9  9  4  5  4  9  8  9  5
#  3  7  4  1  3  6  4  7  9  2  1  4  2  5  1  9  4  1  2  6
# ...
